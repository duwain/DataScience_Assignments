# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2001 = pd.read_csv('2001_results.csv.gz')
df_2000 = pd.read_csv('2000_results.csv.gz')

# %%
df_2001.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg
# 2           2  tt0114447    0.0                               NaN
# 3           3  tt0114722    0.0                               NaN
# 4           4  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN  48000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN         0.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN   11232.0
# 2  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007.0
# ...

# %%
df_merged = df_2000.append(df_2001, ignore_index=True)

# %%
df_merged.head(5)
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0015414    0.0                               NaN
# 2           2  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 3           3  tt0113086    0.0                               NaN
# 4           4  tt0113092    0.0                               NaN
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN         0.0
# 2                   NaN  10000000.0
# 3                   NaN         0.0
# 4                   NaN         0.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1                      [{'id': 18, 'name': 'Drama'}]      NaN  607290.0
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# ...

# %%
#df_merged.dropna(inplace=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3017 entries, 0 to 3016
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3017 non-null   int64
#  1   imdb_id                3017 non-null   object
#  2   adult                  3014 non-null   float64
#  3   backdrop_path          1236 non-null   object
#  4   belongs_to_collection  181 non-null    object
#  5   budget                 3015 non-null   float64
#  6   genres                 3015 non-null   object
#  7   homepage               151 non-null    object
#  8   id                     3015 non-null   float64
#  9   original_language      3015 non-null   object
#  10  original_title         3015 non-null   object
#  11  overview               2735 non-null   object
#  12  popularity             3015 non-null   float64
#  13  poster_path            2509 non-null   object
# ...

# %%
for i in df_merged['budget']:
    if i > 0.0 and i != 'NaN':
        count= df_merged['imdb_id'].value_counts()

# %%
df_merged.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0015414    0.0                               NaN
# 2           2  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 3           3  tt0113086    0.0                               NaN
# 4           4  tt0113092    0.0                               NaN
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN         0.0
# 2                   NaN  10000000.0
# 3                   NaN         0.0
# 4                   NaN         0.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1                      [{'id': 18, 'name': 'Drama'}]      NaN  607290.0
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# ...

# %%
df_merged['has_financial_info'] = df_merged[['budget', 'revenue']]>0
num_movies_with_financial_info = df_merged['has_financial_info'].sum()
print(f'There are {num_movies_with_financial_info} movies with at least some valid financial information.')
# Out:
# There are 386 movies with at least some valid financial information.

# %%
ax = sns.countplot(data=df_merged, x='has_financial_info')

# %%
certification_counts = df_merged['certification'].value_counts()

print(certification_counts)
# Out:
# R          337
# PG-13      144
# NR          88
# PG          63
# G           38
# NC-17       25
# Unrated      1
# Name: certification, dtype: int64

# %%
ax = sns.countplot(data=df_merged, x='certification')

# %%
average_revenue = df_merged.groupby('certification')['revenue'].mean()

print(average_revenue)
# Out:
# certification
# G          3.744950e+07
# NC-17      4.671200e+02
# NR         2.974970e+06
# PG         3.243252e+07
# PG-13      7.066360e+07
# R          1.239749e+07
# Unrated    0.000000e+00
# Name: revenue, dtype: float64

# %%
# Plot the average of each as a bar
fig, ax = plt.subplots()
ax.bar(average_revenue.index, average_revenue.values)
ax.set_ylabel('revenue')
ax.set_xlabel('certification')
# Out:
# Text(0.5, 0, 'certification')

# %%
average_budget = df_merged.groupby('certification')['budget'].mean()

print(average_budget)
# Out:
# certification
# G          1.250000e+07
# NC-17      0.000000e+00
# NR         1.941511e+06
# PG         1.645397e+07
# PG-13      3.159420e+07
# R          8.336647e+06
# Unrated    0.000000e+00
# Name: budget, dtype: float64

# %%
# Plot the average of each as a bar
fig, ax = plt.subplots()
ax.bar(average_budget.index, average_budget.values)
ax.set_ylabel('budget')
ax.set_xlabel('certification')
# Out:
# Text(0.5, 0, 'certification')
